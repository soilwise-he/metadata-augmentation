# %% [markdown]
# # Arena

# %% [markdown]
# Notebook for comparing different models and strategies for augmenting dataset.

# %%
import os
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import labeled dataset

# %%
def get_all_json_files(directory, key_term):
    # List to store paths of JSON files that contain the key term
    json_files = []
    for filename in os.listdir(directory):
        if key_term in filename and filename.endswith('.json'):
            json_files.append(os.path.join(directory, filename))
    return json_files

def merge_jsonfiles(json_files):
    merged_data = {}
    for file_path in json_files:
        with open(file_path, 'r') as file:
            data_file = json.load(file)
            merged_data.update(data_file)

    return merged_data

# %%
directory = 'data'
key_term = 'manual-labels'
json_files = get_all_json_files(directory, key_term)
labeled_dataset = merge_jsonfiles(json_files)
print(list(labeled_dataset.items())[:5])
# Out:
# [('https://esdac.jrc.ec.europa.eu//Eudasm/UK/South-West_Scotland6.jpg', {'labels': ['Scotland'], 'text': 'Soil Survey of Scotland 1:250 000 scale soil map of South West Scotland; Sheet 6 || Soil Survey of Scotland 1:250 000 scale soil map of South West Scotland; Sheet 6'}), ('c01d7dcc-ff05-4773-9c0b-6de920bb2434', {'labels': ['Forst'], 'text': "Web Map Service of the dataset 'Piché evaporation at agroforestry site in Forst, 2019 and 2020' || This Web Map Service includes spatial information used by datasets 'AGIS Map Service of the dataset 'Piché evaporation at agroforestry site in Forst, 2019 and 2020''"}), ('https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kemaiko.jpg', {'labels': ['East Africa'], 'text': '"""Maikona. Sheet """"43"""". Metre Grid (East Africa). Zone H. Series Y633.""" || """Maikona. Sheet """"43"""". Metre Grid (East Africa). Zone H. Series Y633."""'}), ('09adf1ad-a388-40e0-a61f-ba30d300cef9', {'labels': ['Germany'], 'text': "Tree species composition of a landscape in north-eastern Germany in 1780, 1890 and 2010 || This data set contains information about main tree species in 1780 and 1890 derived from different sources. Geodata base is the hand drawn Schmettau Map (1:50.000, ca. 1780) and the Prussian Land Survey (scale 1:25.000, ca. 1890). Additional information from other sources where aligned and added. In total about 200 maps and the same number of archival documents where checked for reconstruction of spatial explicit tree species localities.  This table contains the index of all tables forming this data collection.\n\nRelated datasets are listed in the metadata element 'Related Identifier'.\nDataset version 1.0"}), ('6b664e1e-15ff-4bcb-8cd6-fef048a653a6', {'labels': [], 'text': "Validation and field application of a low-cost device to measure CO2 and ET fluxes - Field ET flux measurements || ET flux measurements from field trial application of low-cost measurement device.\n\nRelated datasets are listed in the metadata element 'Related Identifier'."})]

# %% [markdown]
# ## Evaluation

# %%
Global_eval = {}

# %%
def eval_test(dict_truth,dict_test,return_table = False):
    match_counts = 0
    total_truth = 0
    total_given = 0


    matching_labels_list = []
    non_matching_labels_list = []
    not_found_labels_list = []
    recall_list = []
    text_list = []
    manual_labeled_list = []

    for key, value in dict_truth.items():

        if not key in list(dict_test.keys()):
            continue

        truth_set = set(value['labels'])
        given_set = set(dict_test[key])

        total_truth += len(truth_set)
        total_given += len(given_set)
        match_counts += len(truth_set & given_set)

        # Also appreciate the non-geo entries
        if len(truth_set) == 0: total_truth +=1
        if len(truth_set) == 0 & len(given_set)==0: match_counts +=1
        if len(given_set) == 0: total_given +=1

        matching_labels = truth_set & given_set
        not_found_labels = truth_set.difference(given_set)
        non_matching_labels = given_set.difference(truth_set)
        recall_item = len(truth_set & given_set)/len(truth_set) if len(truth_set) !=0 else 0

        matching_labels_list.append(matching_labels)
        non_matching_labels_list.append(non_matching_labels)
        not_found_labels_list.append(not_found_labels)
        recall_list.append(recall_item)
        text_list.append(value['text'])
        manual_labeled_list.append(truth_set)


    precision = match_counts / total_given if total_given !=0 else 0
    recall = match_counts / total_truth if total_truth !=0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) !=0 else 0

    eval_export = {'precision':precision,
                  'recall':recall,
                  'f1 score': f1_score}
    
    if return_table:
        results_df = pd.DataFrame({
            'Text':text_list,
            'Manual Labeled':manual_labeled_list,
            'Matching Labels': matching_labels_list,
            'Non-Matching Labels': non_matching_labels_list,
            'Not Found Labels':not_found_labels_list,
            'Recall': recall_list
        }, index=dict_truth.keys())

        eval_export['evaluation table']=results_df

    return eval_export

# %%
from geopy.geocoders import Nominatim
from shapely import wkt,unary_union,intersection
from shapely.geometry import Point, Polygon, MultiPolygon, box

# %%
geolocator = Nominatim(user_agent="SWR", timeout=2)
def text_to_geom(label:str):
    location_obj = geolocator.geocode(label, geometry='wkt')

    if not location_obj:
        return

    wkt_string=location_obj.raw["geotext"]
    geometry = wkt.loads(wkt_string)

    # Check if the geometry is a point
    if isinstance(geometry, Point):
        # Get the bounding box from the raw data to have some weight in the evaluation
        bbox = location_obj.raw["boundingbox"]
        if bbox:
            min_lat, max_lat, min_lon, max_lon = map(float, bbox)
            bounding_box_geom = box(min_lon, min_lat, max_lon, max_lat)
            return bounding_box_geom
    elif isinstance(geometry, Polygon) or isinstance(geometry, MultiPolygon):
        return geometry


def eval_test_geo_polygone(dict_truth,dict_test,return_table = False):
    # Evaluation based on percentage common area between 2 dictionaries with common keys
    # based on querying OSM with a geolocation string
    # Remark: still very slow
    
    matching_area_list = []
    precision_area_list = []

    for key, value in dict_truth.items():

        # matching empty datasets returning 100% overlap 
        if len(value['labels']) == 0 & len(dict_test[key])==0:
            matching_area_list.append(1)
            precision_area_list.append(1)
            continue
        
        # making 1 merged polygone of the desired output
        geometries_truth = []
        for location_truth in value['labels']:
            geom = text_to_geom(location_truth)
            if geom: geometries_truth.append(geom)
        merged_geometries_truth = unary_union(geometries_truth)

        # making 1 merged polygone of the found output
        geometries_test = []
        for location_test in dict_test[key]:
            geom = text_to_geom(location_test)
            if geom: geometries_test.append(geom)
        merged_geometries_test = unary_union(geometries_test)

        # calculating percentage intersection
        intersection = merged_geometries_truth.intersection(merged_geometries_test)
        recall_overlap = intersection.area/merged_geometries_truth.area if merged_geometries_truth.area !=0 else 0
        precision_overlap = intersection.area/merged_geometries_test.area if merged_geometries_test.area !=0 else 0
        matching_area_list.append(recall_overlap)
        precision_area_list.append(precision_overlap)

    eval_export = {
                    'precision area':np.mean(precision_area_list),
                    'recall area':np.mean(matching_area_list),
                    }
    
    if return_table:
        results_df = pd.DataFrame({
            'percentage area match':matching_area_list,
            'precision area ':precision_area_list,
        }, index=dict_truth.keys())

        eval_export['evaluation table']=results_df

    return eval_export

# %% [markdown]
# ## GliNER

# %%
import spacy

# %%
labellist = ["geo","location","countries","sample_location"]

# %%
#different SpaCy models that can be downloaded
#!python -m spacy download en_core_web_lg
#!python -m spacy download en_core_web_trf
#!python -m spacy download en_core_web_sm

# %% [markdown]
# 🌟 Available Models GliNER on Hugging Face
#
# 🇬🇧 For English
# * GLiNER Base: urchade/gliner_base (CC BY NC 4.0)
# * GLiNER Small: urchade/gliner_small (CC BY NC 4.0)
# * GLiNER Small v2: urchade/gliner_small-v2 (Apache 2.0)
# * GLiNER Small v2.1: urchade/gliner_small-v2.1 (Apache 2.0)
# * GLiNER Medium: urchade/gliner_medium (CC BY NC 4.0)
# * GLiNER Medium v2: urchade/gliner_medium-v2 (Apache 2.0)
# * GLiNER Medium v2.1: urchade/gliner_medium-v2.1 (Apache 2.0)
# * GLiNER Large: urchade/gliner_large (CC BY NC 4.0)
# * GLiNER Large v2: urchade/gliner_large-v2 (Apache 2.0)
# * GLiNER Large v2.1: urchade/gliner_large-v2.1 (Apache 2.0)
# * GLiNER NuNerZero span: numind/NuNER_Zero-span (MIT) - +4.5% more powerful GLiNER Large v2.1
# * GLiNER News: EmergentMethods/gliner_medium_news-v2.1 (Apache 2.0) 9.5% improvement over GLiNER Large v2.1 on 18 benchmark datasets
#
# 🌍 For Other Languages
# * Korean: 🇰🇷 taeminlee/gliner_ko
# * Italian: 🇮🇹 DeepMount00/universal_ner_ita
# * Multilingual: 🌐 urchade/gliner_multi (CC BY NC 4.0) and urchade/gliner_multi-v2.1 (Apache 2.0)

# %%
nlp = spacy.load('en_core_web_lg')
nlp.add_pipe("gliner_spacy",
    config={
        "gliner_model": "urchade/gliner_multi",
        "labels":labellist,
    }, last=True)
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# c:\Users\vercrume\AppData\Local\miniconda3\envs\SW_Sandbox\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# c:\Users\vercrume\AppData\Local\miniconda3\envs\SW_Sandbox\Lib\site-packages\transformers\convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# c:\Users\vercrume\AppData\Local\miniconda3\envs\SW_Sandbox\Lib\site-packages\gliner\model.py:483: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_file, map_location=torch.device(map_location))

# %%
GliNER_results={}
for key, value in labeled_dataset.items():
    doc = nlp(value['text'])
    locations = []
    for ent in doc.ents:
        locations.append(ent.text)
    GliNER_results[key]= set(locations)

{k: GliNER_results[k] for k in list(GliNER_results)[:10]}
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# {'https://esdac.jrc.ec.europa.eu//Eudasm/UK/South-West_Scotland6.jpg': {'Scotland'},
#  'c01d7dcc-ff05-4773-9c0b-6de920bb2434': {'2020',
#   'Forst',
#   'agroforestry site'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kemaiko.jpg': {'East Africa'},
#  '09adf1ad-a388-40e0-a61f-ba30d300cef9': {'Germany'},
#  '6b664e1e-15ff-4bcb-8cd6-fef048a653a6': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_shlu5c.jpg': {'St. Helena'},
#  '70304e68-c369-4c1b-8d54-79f48bc182c4': {'soil'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/latinamerica/images/maps/download/uy13003_su.jpg': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Asia/images/maps/download/MY3006_4LU.jpg': {'Kuching',
#   'Kuching. Sarawak'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kekili1.jpg': set()}

# %%
eval_GliNER = eval_test(labeled_dataset,GliNER_results,return_table=True)
{print(f"{k}: {v}") for k, v in eval_GliNER.items() if k != 'evaluation table'}
# Out:
# precision: 0.42118863049095606
# recall: 0.6245210727969349
# f1 score: 0.5030864197530863
# {None}

# %%
eval_GliNER_geo = eval_test_geo_polygone(labeled_dataset,GliNER_results,return_table=True)
{print(f"{k}: {v}") for k, v in eval_GliNER_geo.items() if k != 'evaluation table'}
# Out:
# recall area: 0.7091429479492686
# precision area: 0.6734661870519892
# {None}

# %%
merged_dict = {**eval_GliNER, **eval_GliNER_geo}
merged_evaluation_table = pd.concat([eval_GliNER['evaluation table'], eval_GliNER_geo['evaluation table']], axis=1)
merged_dict['evaluation table'] = merged_evaluation_table
Global_eval['GliNER']=merged_dict
Global_eval['GliNER']['evaluation table']
# Out:
#                                                                                                  Text  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...  Soil Survey of Scotland 1:250 000 scale soil m...
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                Web Map Service of the dataset 'Piché evaporat...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  """Maikona. Sheet """"43"""". Metre Grid (East...
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                Tree species composition of a landscape in nor...
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                Validation and field application of a low-cost...
# ...                                                                                               ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Soil Maps of Baradi Area, Baga Area, Jagla Are...
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                Long-term fertilization field experiment Darms...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Carte 1. Indice Xerothermique de l || Carte 1....
# 10.1016/j.agwat.2020.106496                         Effects of rainwater harvesting system on soil...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...  Uitgave Centraal Bureau Luchtkartering Surinam...
#
#                                                                                        Manual Labeled  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...                                         {Scotland}
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                                                          {Forst}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                      {East Africa}
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                                                        {Germany}
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                                                               {}
# ...                                                                                               ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Jagla, Nabharan, Baradi, Baga, Garabaria, Arp...
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                                                      {Darmstadt}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# 10.1016/j.agwat.2020.106496                                                    {Loess Plateau, China}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                                         {Suriname}
#
#                                                            Matching Labels  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...              {Scotland}
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                               {Forst}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...           {East Africa}
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                             {Germany}
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                                    {}
# ...                                                                    ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                      {}
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                           {Darmstadt}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                      {}
# 10.1016/j.agwat.2020.106496                         {Loess Plateau, China}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...              {Suriname}
#
#                                                                                   Non-Matching Labels  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...                                                 {}
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                                        {2020, agroforestry site}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                                                               {}
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                                                               {}
# ...                                                                                               ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Baradi Area, Jagla Area, Baga Area, Nabharan ...
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                                {Germany, farmyard, Berlin, soil}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# 10.1016/j.agwat.2020.106496                         {rainwater harvesting area, deep soil layers, ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                                                 {}
#
#                                                                                      Not Found Labels  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...                                                 {}
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                                                               {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                                                               {}
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                                                               {}
# ...                                                                                               ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Jagla, Nabharan, Baradi, Baga, Garabaria, Arp...
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                                                               {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# 10.1016/j.agwat.2020.106496                                                                        {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                                                 {}
#
#                                                     Recall  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...     1.0
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                   1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     1.0
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                   1.0
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                   0.0
# ...                                                    ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                   1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# 10.1016/j.agwat.2020.106496                            1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...     1.0
#
#                                                     percentage area match  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...                    1.0
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                                  1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    1.0
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                                  1.0
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                                  1.0
# ...                                                                   ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                                  1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    1.0
# 10.1016/j.agwat.2020.106496                                           1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                    1.0
#
#                                                     precision area
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...         1.000000
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                       0.510598
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         1.000000
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                       1.000000
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                       1.000000
# ...                                                             ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                       0.002081
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         1.000000
# 10.1016/j.agwat.2020.106496                                1.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...         1.000000
#
# [173 rows x 8 columns]

# %% [markdown]
# ## LLM

# %% [markdown]
# ### Ollama

# %%
#!pip install ollama

# %%
import ollama

# %%
def keyword_generator(p):
    prompt = "No Bullshit. You are the ultimate human labeler in the world and understand all the soilprojects. You are European and very efficient. Your task is to extract all locations in the text you are given. These locations have to include all the geographic references that this text makes. don't return anything else then the list of locations. Give an export in the form of [location1, location2,...]. Your text is: "+p
    res = ollama.generate(model="llama3", prompt=prompt)["response"]
    print(res)
    return res.replace("\n"," ").strip()

# %%
test = 'Soil Survey of Scotland 1:250 000 scale soil map of South West Scotland; Sheet 6 || Soil Survey of Scotland 1:250 000 scale soil map of South West Scotland; Sheet 6'

# %%
# print(keyword_generator(test))

# %% [markdown]
# ^ ReadError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
# from ollama import Client
# 
# response = client.chat(model='llama3.1', messages=[
#   {
#     'role': 'user',
#     'content': 'Why is the sky blue?',
#   },
# ])

# %%
# import psutil
# for proc in psutil.process_iter():
#     try:
#         if proc.name() == "ollydbg.exe":
#             print("OllyDbg is running.")
#             break  # Stop searching once we find it
#     except (psutil.NoSuchProcess, psutil.AccessDenied, psutil.ZombieProcess):
#         pass

# # If we reach this point without finding OllyDbg, it's likely not running
# print("OllyDbg is not running.")

# %% [markdown]
# ### OpenAI

# %%
import openai
import os
from tenacity import retry, wait_random_exponential, stop_after_attempt
import ast
import re

# %%
OPENAI_MODEL = 'gpt-3.5-turbo-0125'

client = openai.OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

labels = ['Location']

# %% [markdown]
# #### prompt 1

# %%
system_message = f"""
You are an expert in Natural Language Processing. Your task is to identify common Named Entities (NER) in a given text.
The possible common Named Entities (NER) types are exclusively: ({", ".join(labels)})."""

# %%
# One-shot approach
def assisstant_message():
    return f"""
EXAMPLE:
    Text: 'Soil Maps of Baradi Area, Baga Area, Jagla Area, Garabaria Area, Nabharan Area, Kaliganj Area and Arpara Area. || Soil Maps of Baradi Area, Baga Area, Jagla Area, Garabaria Area, Nabharan Area, Kaliganj Area and Arpara Area.'
    {{
        "Location": ["Baradi","Baga","Jagla","Garabaria","Nabharan","Kaliganj","Arpara"]
    }}
--"""

# %%
def user_message(text):
    return f"""
TASK:
    Text: {text}
"""

# %%
@retry(wait=wait_random_exponential(min=1, max=10), stop=stop_after_attempt(5))
def run_openai_task(labels, text):
    messages = [
          {"role": "system", "content": system_message},
          {"role": "assistant", "content": assisstant_message()},
          {"role": "user", "content": user_message(text=text)}
      ]

    response = openai.chat.completions.create(
        temperature=0,
        model=OPENAI_MODEL,
        messages=messages,
    )

    return {"model_response": response}

# %%
OpenAI_results_1={}
for key, value in labeled_dataset.items():
    result = run_openai_task(labels, value['text'])
    message = result['model_response'].choices[0].message.content
    matches = re.findall(r'\{[^}]*\}', message)
    dict_message = ast.literal_eval(matches[0])
    OpenAI_results_1[key]= set(dict_message['Location'])


{k: OpenAI_results_1[k] for k in list(OpenAI_results_1)[:10]}
# Out:
# {'https://esdac.jrc.ec.europa.eu//Eudasm/UK/South-West_Scotland6.jpg': {'Scotland',
#   'South West Scotland'},
#  'c01d7dcc-ff05-4773-9c0b-6de920bb2434': {'Forst'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kemaiko.jpg': {'East Africa',
#   'Maikona'},
#  '09adf1ad-a388-40e0-a61f-ba30d300cef9': {'Germany'},
#  '6b664e1e-15ff-4bcb-8cd6-fef048a653a6': {'Field'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_shlu5c.jpg': {'St. Helena'},
#  '70304e68-c369-4c1b-8d54-79f48bc182c4': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/latinamerica/images/maps/download/uy13003_su.jpg': {'Laguna Merin'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Asia/images/maps/download/MY3006_4LU.jpg': {'Kuching',
#   'Sarawak'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kekili1.jpg': {'Kilifi'}}

# %%
eval_OpenAI_1 = eval_test(labeled_dataset,OpenAI_results_1,return_table=True)
{print(f"{k}: {v}") for k, v in eval_OpenAI_1.items() if k != 'evaluation table'}
# Out:
# precision: 0.7303370786516854
# recall: 0.7471264367816092
# f1 score: 0.7386363636363638
# {None}

# %%
eval_OpenAI1_geo = eval_test_geo_polygone(labeled_dataset,OpenAI_results_1,return_table=True)
{print(f"{k}: {v}") for k, v in eval_OpenAI1_geo.items() if k != 'evaluation table'}
# Out:
# recall area: 0.8398818664682381
# precision area: 0.7868782326092603
# {None}

# %%
merged_dict = {**eval_OpenAI_1, **eval_OpenAI1_geo}
merged_evaluation_table = pd.concat([eval_OpenAI_1['evaluation table'], eval_OpenAI1_geo['evaluation table']], axis=1)
merged_dict['evaluation table'] = merged_evaluation_table
Global_eval['OpenAI_1']=merged_dict
Global_eval['OpenAI_1']['evaluation table']
# Out:
#                                                                                                  Text  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...  Soil Survey of Scotland 1:250 000 scale soil m...
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                Web Map Service of the dataset 'Piché evaporat...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  """Maikona. Sheet """"43"""". Metre Grid (East...
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                Tree species composition of a landscape in nor...
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                Validation and field application of a low-cost...
# ...                                                                                               ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Soil Maps of Baradi Area, Baga Area, Jagla Are...
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                Long-term fertilization field experiment Darms...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Carte 1. Indice Xerothermique de l || Carte 1....
# 10.1016/j.agwat.2020.106496                         Effects of rainwater harvesting system on soil...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...  Uitgave Centraal Bureau Luchtkartering Surinam...
#
#                                                                                        Manual Labeled  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...                                         {Scotland}
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                                                          {Forst}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                      {East Africa}
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                                                        {Germany}
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                                                               {}
# ...                                                                                               ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Jagla, Nabharan, Baradi, Baga, Garabaria, Arp...
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                                                      {Darmstadt}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# 10.1016/j.agwat.2020.106496                                                    {Loess Plateau, China}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                                         {Suriname}
#
#                                                                                       Matching Labels  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...                                         {Scotland}
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                                                          {Forst}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                      {East Africa}
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                                                        {Germany}
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                                                               {}
# ...                                                                                               ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Jagla, Nabharan, Baradi, Baga, Garabaria, Arp...
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                                                      {Darmstadt}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# 10.1016/j.agwat.2020.106496                                                    {Loess Plateau, China}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                                         {Suriname}
#
#                                                         Non-Matching Labels  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...    {South West Scotland}
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                                     {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                {Maikona}
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                                     {}
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                                {Field}
# ...                                                                     ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                       {}
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                      {Germany, Berlin}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                       {}
# 10.1016/j.agwat.2020.106496                         {Chinese Loess Plateau}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                       {}
#
#                                                    Not Found Labels  Recall  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...               {}     1.0
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                             {}     1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...               {}     1.0
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                             {}     1.0
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                             {}     0.0
# ...                                                             ...     ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...               {}     1.0
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                             {}     1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...               {}     0.0
# 10.1016/j.agwat.2020.106496                                      {}     1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...               {}     1.0
#
#                                                     percentage area match  \
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...                    1.0
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                                  1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    1.0
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                                  1.0
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                                  1.0
# ...                                                                   ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    1.0
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                                  1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    1.0
# 10.1016/j.agwat.2020.106496                                           1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                    1.0
#
#                                                     precision area
# https://esdac.jrc.ec.europa.eu//Eudasm/UK/South...         1.000000
# c01d7dcc-ff05-4773-9c0b-6de920bb2434                       1.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000006
# 09adf1ad-a388-40e0-a61f-ba30d300cef9                       1.000000
# 6b664e1e-15ff-4bcb-8cd6-fef048a653a6                       1.000000
# ...                                                             ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         1.000000
# 7f667e39-7f6a-40a9-8e1e-4efda1ecbfe3                       0.002081
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         1.000000
# 10.1016/j.agwat.2020.106496                                1.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...         1.000000
#
# [173 rows x 8 columns]

# %% [markdown]
# #### prompt 2

# %%
system_message = """
You are an expert in Natural Language Processing. Your task is to identify common Named Entities (NER) in a given text.
The possible common Named Entities (NER) type is exclusively: "Location". However, only locations applicable to the research for which you receive the abstract and title.
If no location is found, an empty dict is returned. You also ensure that all entities you return can be mapped unambiguously."""

# %%
OpenAI_results_2={}
for key, value in labeled_dataset.items():
    result = run_openai_task(labels, value['text'])
    message = result['model_response'].choices[0].message.content
    matches = re.findall(r'\{[^}]*\}', message)
    dict_message = ast.literal_eval(matches[0])
    OpenAI_results_2[key]= set(dict_message['Location']) if dict_message else set()


{k: OpenAI_results_2[k] for k in list(OpenAI_results_2)[:10]}
# Out:
# {'https://esdac.jrc.ec.europa.eu//Eudasm/UK/South-West_Scotland6.jpg': {'Scotland',
#   'South West Scotland'},
#  'c01d7dcc-ff05-4773-9c0b-6de920bb2434': {'Forst'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kemaiko.jpg': {'East Africa',
#   'Maikona'},
#  '09adf1ad-a388-40e0-a61f-ba30d300cef9': {'Germany'},
#  '6b664e1e-15ff-4bcb-8cd6-fef048a653a6': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_shlu5c.jpg': {'St. Helena'},
#  '70304e68-c369-4c1b-8d54-79f48bc182c4': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/latinamerica/images/maps/download/uy13003_su.jpg': {'Laguna Merin'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Asia/images/maps/download/MY3006_4LU.jpg': {'Kuching',
#   'Sarawak'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kekili1.jpg': {'Kilifi'}}

# %%
eval_OpenAI_2 = eval_test(labeled_dataset,OpenAI_results_2,return_table=True)
{print(f"{k}: {v}") for k, v in eval_OpenAI_2.items() if k != 'evaluation table'}
# Out:
# precision: 0.7450980392156863
# recall: 0.7279693486590039
# f1 score: 0.7364341085271319
# {None}

# %%
eval_OpenAI2_geo = eval_test_geo_polygone(labeled_dataset,OpenAI_results_2,return_table=True)
{print(f"{k}: {v}") for k, v in eval_OpenAI2_geo.items() if k != 'evaluation table'}
# Out:
# recall area: 0.8225546253394379
# precision area: 0.7745094507844615
# {None}

# %%
merged_dict = {**eval_OpenAI_2, **eval_OpenAI2_geo}
merged_evaluation_table = pd.concat([eval_OpenAI_2['evaluation table'], eval_OpenAI2_geo['evaluation table']], axis=1)
merged_dict['evaluation table'] = merged_evaluation_table
Global_eval['OpenAI_2']=merged_dict
Global_eval['OpenAI_2']['evaluation table'].sort_values(by=['Recall'])[:20]
# Out:
#                                                                                                  Text  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...  General Soil Map Kauai Island Hawaii || Genera...
# 8ef45947-3c2a-4bbf-896f-796cb2593af8                Web Map Service of the dataset 'Spectra LUCAS ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     Soils map of Nigeria. || Soils map of Nigeria.
# 3fcd463d-3d28-401e-9fc3-d4a8ad2a9df4                Soil and rhizosphere properties related to car...
# 10.1016/j.geoderma.2020.114851                      Fusion of Vis-NIR and XRF spectra for estimati...
# 4d3c311c-4272-4562-92b9-0e723462f4a8                Earthworm Biodiversity Data Lietzen I - Earthw...
# fbdd1c72-5681-4b93-9ce3-39889667d055                WMS Service of the dataset 'Cropland agrofores...
# https://esdac.jrc.ec.europa.eu/resource-type/do...  Advances in soil erosion modelling through rem...
# https://esdac.jrc.ec.europa.eu/resource-type/do...  Agricultural Adaptation to Climate Change || A...
# https://esdac.jrc.ec.europa.eu/resource-type/do...  Biochar application to soils || Biochar applic...
# 10.1016/j.scitotenv.2021.147527                     Cerium, gadolinium, lanthanum, and neodymium e...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Soil Map of Aghili Plains. Khuzistan. Iran. ||...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Plantations, Species & Age Classes. Map 1. D.O...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Soil Map of Arab Countries. Sudan Democratic R...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/E...  Types of Agriculture Map of Europe || Types of...
# 4a90cb4d-957f-480d-b109-f7b3981cd58d                Effect of N fertilizers on yield, N-uptake, an...
# 10.1016/j.scitotenv.2020.144026                     Treated wastewater reuse for irrigation: Pros ...
# 2e1eeba3-97f8-43c1-8d20-ba4870a236f4                Effect of N fertilizers on yield, N-uptake, an...
# https://esdac.jrc.ec.europa.eu/resource-type/do...  Progress and challenges in sustainable land ma...
# 10.1016/j.enggeo.2016.09.005                        A general analytical solution for the evolutio...
#
#                                                                  Manual Labeled  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...        {Kauai Island Hawaii}
# 8ef45947-3c2a-4bbf-896f-796cb2593af8                                         {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    {Nigeria}
# 3fcd463d-3d28-401e-9fc3-d4a8ad2a9df4                             {Hohenschulen}
# 10.1016/j.geoderma.2020.114851                                               {}
# 4d3c311c-4272-4562-92b9-0e723462f4a8                                         {}
# fbdd1c72-5681-4b93-9ce3-39889667d055                                         {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...         {Europa, EU, Europe}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                           {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                           {}
# 10.1016/j.scitotenv.2021.147527                                              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...          {Aghili, Khuzistan}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                           {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Sudan Democratic Republic}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/E...                     {Europe}
# 4a90cb4d-957f-480d-b109-f7b3981cd58d                                         {}
# 10.1016/j.scitotenv.2020.144026                                              {}
# 2e1eeba3-97f8-43c1-8d20-ba4870a236f4                                         {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                           {}
# 10.1016/j.enggeo.2016.09.005                                                 {}
#
#                                                    Matching Labels  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...              {}
# 8ef45947-3c2a-4bbf-896f-796cb2593af8                            {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# 3fcd463d-3d28-401e-9fc3-d4a8ad2a9df4                            {}
# 10.1016/j.geoderma.2020.114851                                  {}
# 4d3c311c-4272-4562-92b9-0e723462f4a8                            {}
# fbdd1c72-5681-4b93-9ce3-39889667d055                            {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...              {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...              {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...              {}
# 10.1016/j.scitotenv.2021.147527                                 {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/E...              {}
# 4a90cb4d-957f-480d-b109-f7b3981cd58d                            {}
# 10.1016/j.scitotenv.2020.144026                                 {}
# 2e1eeba3-97f8-43c1-8d20-ba4870a236f4                            {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...              {}
# 10.1016/j.enggeo.2016.09.005                                    {}
#
#                                                                              Non-Matching Labels  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...                        {Kauai Island, Hawaii}
# 8ef45947-3c2a-4bbf-896f-796cb2593af8                                                   {BonaRes}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                            {}
# 3fcd463d-3d28-401e-9fc3-d4a8ad2a9df4                                                          {}
# 10.1016/j.geoderma.2020.114851                                                                {}
# 4d3c311c-4272-4562-92b9-0e723462f4a8                                                   {Lietzen}
# fbdd1c72-5681-4b93-9ce3-39889667d055                                                          {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                                    {European}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                                            {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                                            {}
# 10.1016/j.scitotenv.2021.147527                                                               {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {Iran, Aghili Plains, Khuzestan}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                            {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Democratic Republic, Arab Countries, Sudan}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/E...                                            {}
# 4a90cb4d-957f-480d-b109-f7b3981cd58d                                                          {}
# 10.1016/j.scitotenv.2020.144026                                                               {}
# 2e1eeba3-97f8-43c1-8d20-ba4870a236f4                                                          {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                                      {global}
# 10.1016/j.enggeo.2016.09.005                                                                  {}
#
#                                                                Not Found Labels  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...        {Kauai Island Hawaii}
# 8ef45947-3c2a-4bbf-896f-796cb2593af8                                         {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    {Nigeria}
# 3fcd463d-3d28-401e-9fc3-d4a8ad2a9df4                             {Hohenschulen}
# 10.1016/j.geoderma.2020.114851                                               {}
# 4d3c311c-4272-4562-92b9-0e723462f4a8                                         {}
# fbdd1c72-5681-4b93-9ce3-39889667d055                                         {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...         {Europa, EU, Europe}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                           {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                           {}
# 10.1016/j.scitotenv.2021.147527                                              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...          {Aghili, Khuzistan}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                           {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Sudan Democratic Republic}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/E...                     {Europe}
# 4a90cb4d-957f-480d-b109-f7b3981cd58d                                         {}
# 10.1016/j.scitotenv.2020.144026                                              {}
# 2e1eeba3-97f8-43c1-8d20-ba4870a236f4                                         {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                           {}
# 10.1016/j.enggeo.2016.09.005                                                 {}
#
#                                                     Recall  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...     0.0
# 8ef45947-3c2a-4bbf-896f-796cb2593af8                   0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# 3fcd463d-3d28-401e-9fc3-d4a8ad2a9df4                   0.0
# 10.1016/j.geoderma.2020.114851                         0.0
# 4d3c311c-4272-4562-92b9-0e723462f4a8                   0.0
# fbdd1c72-5681-4b93-9ce3-39889667d055                   0.0
# https://esdac.jrc.ec.europa.eu/resource-type/do...     0.0
# https://esdac.jrc.ec.europa.eu/resource-type/do...     0.0
# https://esdac.jrc.ec.europa.eu/resource-type/do...     0.0
# 10.1016/j.scitotenv.2021.147527                        0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/E...     0.0
# 4a90cb4d-957f-480d-b109-f7b3981cd58d                   0.0
# 10.1016/j.scitotenv.2020.144026                        0.0
# 2e1eeba3-97f8-43c1-8d20-ba4870a236f4                   0.0
# https://esdac.jrc.ec.europa.eu/resource-type/do...     0.0
# 10.1016/j.enggeo.2016.09.005                           0.0
#
#                                                     percentage area match  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...           1.000000e+00
# 8ef45947-3c2a-4bbf-896f-796cb2593af8                         1.000000e+00
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...           0.000000e+00
# 3fcd463d-3d28-401e-9fc3-d4a8ad2a9df4                         0.000000e+00
# 10.1016/j.geoderma.2020.114851                               1.000000e+00
# 4d3c311c-4272-4562-92b9-0e723462f4a8                         1.000000e+00
# fbdd1c72-5681-4b93-9ce3-39889667d055                         1.000000e+00
# https://esdac.jrc.ec.europa.eu/resource-type/do...           4.000000e-12
# https://esdac.jrc.ec.europa.eu/resource-type/do...           1.000000e+00
# https://esdac.jrc.ec.europa.eu/resource-type/do...           1.000000e+00
# 10.1016/j.scitotenv.2021.147527                              1.000000e+00
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...           0.000000e+00
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...           1.000000e+00
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...           0.000000e+00
# https://esdac.jrc.ec.europa.eu//images/Eudasm/E...           0.000000e+00
# 4a90cb4d-957f-480d-b109-f7b3981cd58d                         1.000000e+00
# 10.1016/j.scitotenv.2020.144026                              1.000000e+00
# 2e1eeba3-97f8-43c1-8d20-ba4870a236f4                         1.000000e+00
# https://esdac.jrc.ec.europa.eu/resource-type/do...           1.000000e+00
# 10.1016/j.enggeo.2016.09.005                                 1.000000e+00
#
#                                                     precision area
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...         0.051037
# 8ef45947-3c2a-4bbf-896f-796cb2593af8                       1.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# 3fcd463d-3d28-401e-9fc3-d4a8ad2a9df4                       0.000000
# 10.1016/j.geoderma.2020.114851                             1.000000
# 4d3c311c-4272-4562-92b9-0e723462f4a8                       1.000000
# fbdd1c72-5681-4b93-9ce3-39889667d055                       1.000000
# https://esdac.jrc.ec.europa.eu/resource-type/do...         1.000000
# https://esdac.jrc.ec.europa.eu/resource-type/do...         1.000000
# https://esdac.jrc.ec.europa.eu/resource-type/do...         1.000000
# 10.1016/j.scitotenv.2021.147527                            1.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         1.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/E...         0.000000
# 4a90cb4d-957f-480d-b109-f7b3981cd58d                       1.000000
# 10.1016/j.scitotenv.2020.144026                            1.000000
# 2e1eeba3-97f8-43c1-8d20-ba4870a236f4                       1.000000
# https://esdac.jrc.ec.europa.eu/resource-type/do...         1.000000
# 10.1016/j.enggeo.2016.09.005                               1.000000

# %% [markdown]
# ## Hybrid

# %% [markdown]
# Trying to finetune the zero-shot SpaCy models with 1 query to a LLM

# %%
sLM_label = GliNER_results
{k: sLM_label[k] for k in list(sLM_label)[:10]}
# Out:
# {'https://esdac.jrc.ec.europa.eu//Eudasm/UK/South-West_Scotland6.jpg': {'Scotland'},
#  'c01d7dcc-ff05-4773-9c0b-6de920bb2434': {'2020',
#   'Forst',
#   'agroforestry site'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kemaiko.jpg': {'East Africa'},
#  '09adf1ad-a388-40e0-a61f-ba30d300cef9': {'Germany'},
#  '6b664e1e-15ff-4bcb-8cd6-fef048a653a6': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_shlu5c.jpg': {'St. Helena'},
#  '70304e68-c369-4c1b-8d54-79f48bc182c4': {'soil'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/latinamerica/images/maps/download/uy13003_su.jpg': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Asia/images/maps/download/MY3006_4LU.jpg': {'Kuching',
#   'Kuching. Sarawak'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kekili1.jpg': set()}

# %%
All_response = set()
for _,set_response in sLM_label.items():
    All_response.update(set_response)
print(len(All_response))
print(All_response)
# Out:
# 300
# {'site', 'Lany Farm', 'North Africa', 'Swabian', 'Tunisie', 'Jaguaribe/Natal', 'Afrika', 'Soilscores', 'Macapá', 'European agricultural soils', 'compost', 'Garabaria Area', 'Kazakh SSR', 'USSR', 'Timor', 'Africa', 'Buyuk Konya Havzasinin Toprak Haritasi.', 'Western Balkans', 'Tensift-basin', 'topsoil', 'Ceylon', 'longitude', 'research sites', 'loam silt', 'Pakistan', 'temperate forest subsoils', 'soil layers', 'Rhodesia', 'North Hessian Hill Country', 'Dornburg', 'Changwat Rayong', 'Nakhonnayok Province. Legend.', 'European', 'Nigeria', 'Crete', 'Southern Europe', 'Marsabit district', 'Bulgaria', 'construction sites', 'humusarmen', 'experimental sites', 'Pusté Jakartice', 'F5 field', 'Light Source', 'region', 'Arpara Area', 'West Africa', 'Formations Végétales et Domaine Forestier National de Madagascar', 'European Vineyard Soils', 'subduction‐zone regions', 'plot A12_12', 'Guadalajara', 'volcanic ash', 'Rostock', 'New Dykesite', 'Kulbacksliden', 'Saskatoon', 'China', 'land uses', 'soil', 'Wagna', 'Old Dyke site', 'Hesse', 'Iran', 'rain-fed orchards', 'Sri-Lanka', 'Ghazni Valley', 'weed strip', 'Pico da Neblina', 'Kuching', 'Mbozi Area', 'Vavuniya District. Land Use.', 'Kremikovtsi', 'rock P', 'Bauchi Plains', 'République du Tchad', 'magmatic ash', 'Suid-Afrika', 'test sites', 'South America', 'predator communities', 'Hohes Gras', 'Ackerböden', 'Bodemcaart', 'farmyard', 'Island Of Hawaii', 'Malaysia', 'Soils Of Kansas', 'cropland', 'Europe', 'Baradi Area', 'soil layer', 'Ruzyne', 'Hessian Hill Country', 'plot E1_13', 'Peru', 'Scotland', 'Chanthaburi Province', 'Litavka River', 'European topsoils', 'Braszowice', 'Neu-Eichenberg', 'East Africa', 'semi-arid lands', 'Austria', 'Fuhrberger Feld', 'natural slopes', 'Wajir District', 'Brandenburg', 'Jagla Area', 'F4', 'Netherlands', 'Hohenschulen', 'local climate', 'UK', 'experimental site', 'Windhindernissen', 'agricultural area', 'Trial Dikopshof', 'Província de Maputo', 'Chinese', 'deep soil layers', 'Marsabit District', 'Algerien', 'regionale Schwerpunkte', 'hill slope', 'rainwater harvesting area', 'D.O.S.', 'Soil', 'Catchments', 'Interior Alaska', 'Mandera District', 'subduction interface', 'Bassin Inferieur du Mekong', 'status level', 'tree row edge', 'reference plot', 'Aalten', 'Sweden', 'soils', 'Algeria', 'slope', 'open cropland', 'Turin', 'Federal Republic of Germany', 'Zwolle', 'Rivers State', 'Hohenschulen field site', 'geological formation', 'Limbang. Sarawak', 'overriding crust', 'XCT', 'Winschoten', 'Papua New Guinea', 'Germany', 'F5', 'agroforestry plot', 'Weser-Leine mountain region', 'Aghili Plains', 'Czech Republic', 'rock mechanics', 'ash', 'plant samples', 'outside', 'Dornburg Conventional', 'Valkenswaard', 'Loess Plateau', 'Serbia', 'Forst', 'Malaya', 'Vegetation', 'altitude', 'ALKIS', 'Lower Mekong Basin', 'cultivation region', 'EOMs', 'wetted areas', 'Nordafrika', 'arid', 'arable fields', 'Ostan VII', 'Landforms', 'Slovakia', 'Bad Lauchstädt', 'Catchment', 'Morocco', 'South Africa', 'Landforms and Soils', 'Huatabampo G12-6', 'Domäne Frankenhausen', 'Sverige', 'lysimeters', 'Nischwitz', 'loess', 'Berlin', 'Spanish', 'Kaliganj Area', 'République Populaire du Bénin', 'Sudan Democratic Republic', 'Tehran-Garmsar', 'Kerema-Vailala Area', 'olive groves', 'Carte Agricole de l', 'Suriname', 'Kauai Island Hawaii', 'Habitats', 'soil type', 'Northern Germany', 'Baga Area', 'Nabharan Area', 'soil climate region', 'farm', 'agroforestry site', 'Poland', 'Vierlingsbeek', 'Gülzow', 'Dikopshof', 'field-derived soil', 'zeolites', 'Tunesien', 'geological deposits', 'Darmstadt', 'United States', 'Khuzistan Plains', 'River waters', 'sandigen', 'ZALF Focus Area - Paulinenaue', 'Colombo', 'West Malaysia', 'sub-area', 'City of Turin', 'Sarawak', 'V140 Muencheberg', 'Republica de el Salvador', 'sampling point', 'terrain', 'Canadian', 'Hawaii', 'field margins', 'Rhenen', 'Khuzistan', 'Lower Mgeta Area', 'Zimbabwe', 'SXRMB beamline', 'Carta de Solos.', 'cliffs', 'Luvisols', 'soil sampl ...

# %%
system_message_1 = """You are an expert in geographical entities with specialized knowledge of OpenStreetMap and Nominatim. Your task is to filter a list of geographical entities, retaining only those that have clearly delineatable locations, such as continents, countries, states, regions, counties, cities, towns, neighborhoods, and street names.

Be cautious when filtering: if a label could plausibly represent a specific, mappable location, it should be retained. Only exclude terms that are highly ambiguous or are clearly more likely to refer to general, non-delineatable locations. For example, "site" should only be excluded if it is clearly intended to represent a general area rather than a specific town or place."""

system_message_2 = """You are an expert in geographical entities with specialized knowledge of OpenStreetMap and Nominatim. Your task is to filter a list of geographical entities, retaining only those that have clearly delineatable locations, such as continents, countries, states, regions, counties, cities, towns, neighborhoods, and street names.

Be cautious when filtering: if a label could plausibly represent a specific, mappable location, it should be retained. Only exclude terms that are highly ambiguous or are clearly more likely to refer to general, non-delineatable locations. For example, "site" should only be excluded if it is clearly intended to represent a general area rather than a specific town or place.

Additionally, if a label is not directly mappable but can be slightly modified to match a specific location (e.g., "West Germany" to "Germany" or "London Area" to "London"), return a dictionary of these changes, where the original label is the key and the modified, mappable location is the value."""

# %%
assisstant_message_1= """
EXAMPLE:
    Text: {'soil,Belgium,creek,street,West-Vlaanderen,river,Wetland,Lucerne,Pays de la Loire,F4,Rijnland-Palts'} 
    {
        "delineatable": ["Belgium","West-Vlaanderen","Lucerne","Pays de la Loire","Rijnland-Palts"],
        "Non-delineatable": ["soil","creek","river","Wetland","F4"]
    }
"""
assisstant_message_2= """
EXAMPLE:
    Text: {'soil,Belgium,creek,street,West-Vlaanderen,river,Wetland,Lucerne,Pays de la Loire,F4,Rijnland-Palts,London Area'} 
    {
        "delineatable": ["Belgium","West-Vlaanderen","Lucerne","Pays de la Loire","Rijnland-Palts","London"],
        "Non-delineatable": ["soil","creek","river","Wetland","F4"],
        "changes":{"London Area":"London"}
    }
"""

# %%
def user_message(text):
    return f"""
TASK:
    Text: {text}
"""

# %%
@retry(wait=wait_random_exponential(min=1, max=10), stop=stop_after_attempt(5))
def run_openai_task_filter(text, system_message,assisstant_message):
    messages = [
          {"role": "system", "content": system_message},
          {"role": "assistant", "content": assisstant_message},
          {"role": "user", "content": user_message(text=text)}
      ]

    response = openai.chat.completions.create(
        temperature=0,
        model=OPENAI_MODEL,
        messages=messages,
    )

    return {"model_response": response}

# %%
result_hybrid = run_openai_task_filter(All_response, system_message_1, assisstant_message_1)

# %%
message_hybrid = result_hybrid['model_response'].choices[0].message.content
try:
    dict_message_hybrid = ast.literal_eval(message_hybrid)
except (ValueError, SyntaxError):
    matches_hybrid = re.findall(r'\{[^}]*\}', message_hybrid)
    dict_message_hybrid = ast.literal_eval(matches_hybrid[0])

if "changes" in list(dict_message_hybrid.keys()):
    sLM_label_1 = {key: {dict_message_hybrid["changes"].get(label, label) for label in value} for key, value in sLM_label.items()}
else:
    sLM_label_1=sLM_label

ok_entities = set(dict_message_hybrid['delineatable'])
cleaned_hybrid_dict = {key: value.intersection(ok_entities) for key, value in sLM_label_1.items()}
{k: cleaned_hybrid_dict[k] for k in list(cleaned_hybrid_dict)[:10]}
# Out:
# {'https://esdac.jrc.ec.europa.eu//Eudasm/UK/South-West_Scotland6.jpg': {'Scotland'},
#  'c01d7dcc-ff05-4773-9c0b-6de920bb2434': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kemaiko.jpg': set(),
#  '09adf1ad-a388-40e0-a61f-ba30d300cef9': {'Germany'},
#  '6b664e1e-15ff-4bcb-8cd6-fef048a653a6': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_shlu5c.jpg': {'St. Helena'},
#  '70304e68-c369-4c1b-8d54-79f48bc182c4': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/latinamerica/images/maps/download/uy13003_su.jpg': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Asia/images/maps/download/MY3006_4LU.jpg': {'Kuching'},
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kekili1.jpg': set()}

# %%
eval_Hybrid = eval_test(labeled_dataset,cleaned_hybrid_dict,return_table=True)
{print(f"{k}: {v}") for k, v in eval_Hybrid.items() if k != 'evaluation table'}
# Out:
# precision: 0.4835164835164835
# recall: 0.3371647509578544
# f1 score: 0.3972911963882619
# {None}

# %%
eval_Hybrid_geo = eval_test_geo_polygone(labeled_dataset,cleaned_hybrid_dict,return_table=True)
{print(f"{k}: {v}") for k, v in eval_Hybrid_geo.items() if k != 'evaluation table'}
# Out:
# recall area: 0.518784194897132
# precision area: 0.4986771262387808
# {None}

# %%
merged_dict = {**eval_Hybrid, **eval_Hybrid_geo}
merged_evaluation_table = pd.concat([eval_Hybrid['evaluation table'], eval_Hybrid_geo['evaluation table']], axis=1)
merged_dict['evaluation table'] = merged_evaluation_table
Global_eval['Hybrid_1']=merged_dict
Global_eval['Hybrid_1']['evaluation table'].sort_values(by=['Recall'])[:20]
# Out:
#                                                                                                  Text  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...  General Soil Map Kauai Island Hawaii || Genera...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Present Land Use. West Malaysia. Sheet 1. || P...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Vavuniya District. Land Use. || Vavuniya Distr...
# f5bcf938-44cc-41fd-8d03-5543933d1d79                Web Map Service of the dataset 'Permafrost deg...
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                                           | || |
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Colombo and Kalutara Districts. Land Use. || C...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/S...  Soil Map Slovakia - pody || Soil Map Slovakia ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  land Use Map of Diful II Project. Ostan VII Ir...
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                WMS Service of datasets from the 'ZALF Focus A...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Soil Map. The Jilga Valley. Vol. IV-13. || Soi...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...  South America. Potential Population Supporting...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Enarotali. Seri IND-B1 Lembar M13-4. Edisi 1. ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Regional Map of Land Resources and Potentialit...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Generalized Map of the Great Soil Groups of th...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  """Kijabe. Sheet """"134/3"""". Y731 (D.O.S. 4...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Formations Végétales et Domaine Forestier Nati...
# b89da85c-84e8-4664-b138-86faeb5ae2f8                Long-Term Fertilization Trial Dikopshof Descri...
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...  Bodemkaart van Nederland Zwolle || Bodemkaart ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...  Carta Edapologica - Estardos Unidos Mexicanos ...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  """Kangondi. Soil Survey. Sheet """"150/1""""....
#
#                                                                                        Manual Labeled  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...                              {Kauai Island Hawaii}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                          {Malaysia, West Malaysia}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                {Vavuniya District}
# f5bcf938-44cc-41fd-8d03-5543933d1d79                                                         {Alaska}
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                                               {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Colombo District, Kalutara District, Kalutara...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/S...                                         {Slovakia}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                             {Iran}
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                                                    {Paulinenaue}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                            {Jilga}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                                    {South America}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                        {Enarotali}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                  {Garmsar, Tehran}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                        {Khuzistan}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                       {Madagascar}
# b89da85c-84e8-4664-b138-86faeb5ae2f8                                                      {Dikopshof}
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...                         {Nederland Zwolle, Zwolle}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                            {Huatabampo, Mexicanos}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                         {Kangondi}
#
#                                                    Matching Labels  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# f5bcf938-44cc-41fd-8d03-5543933d1d79                            {}
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                            {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/S...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                            {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# b89da85c-84e8-4664-b138-86faeb5ae2f8                            {}
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
#
#                                                    Non-Matching Labels  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# f5bcf938-44cc-41fd-8d03-5543933d1d79                                {}
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/S...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                                {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# b89da85c-84e8-4664-b138-86faeb5ae2f8                                {}
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
#
#                                                                                      Not Found Labels  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...                              {Kauai Island Hawaii}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                          {Malaysia, West Malaysia}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                {Vavuniya District}
# f5bcf938-44cc-41fd-8d03-5543933d1d79                                                         {Alaska}
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                                               {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Colombo District, Kalutara District, Kalutara...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/S...                                         {Slovakia}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                             {Iran}
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                                                    {Paulinenaue}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                            {Jilga}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                                    {South America}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                        {Enarotali}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                  {Garmsar, Tehran}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                        {Khuzistan}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                       {Madagascar}
# b89da85c-84e8-4664-b138-86faeb5ae2f8                                                      {Dikopshof}
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...                         {Nederland Zwolle, Zwolle}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                            {Huatabampo, Mexicanos}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                         {Kangondi}
#
#                                                     Recall  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# f5bcf938-44cc-41fd-8d03-5543933d1d79                   0.0
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                   0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/S...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                   0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# b89da85c-84e8-4664-b138-86faeb5ae2f8                   0.0
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
#
#                                                     percentage area match  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# f5bcf938-44cc-41fd-8d03-5543933d1d79                                  0.0
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                  1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/S...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                                  0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# b89da85c-84e8-4664-b138-86faeb5ae2f8                                  0.0
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
#
#                                                     precision area
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0
# f5bcf938-44cc-41fd-8d03-5543933d1d79                            0.0
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                            1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/S...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                            0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0
# b89da85c-84e8-4664-b138-86faeb5ae2f8                            0.0
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...              0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              0.0

# %%
result_hybrid = run_openai_task_filter(All_response, system_message_2, assisstant_message_2)

message_hybrid = result_hybrid['model_response'].choices[0].message.content
try:
    dict_message_hybrid = ast.literal_eval(message_hybrid)
except (ValueError, SyntaxError):
    matches_hybrid = re.findall(r'\{[^}]*\}', message_hybrid)
    dict_message_hybrid = ast.literal_eval(matches_hybrid[0])

if "changes" in list(dict_message_hybrid.keys()):
    sLM_label_1 = {key: {dict_message_hybrid["changes"].get(label, label) for label in value} for key, value in sLM_label.items()}
else:
    sLM_label_1=sLM_label

ok_entities = set(dict_message_hybrid['delineatable'])
cleaned_hybrid_dict = {key: value.intersection(ok_entities) for key, value in sLM_label_1.items()}
{k: cleaned_hybrid_dict[k] for k in list(cleaned_hybrid_dict)[:10]}
# Out:
# {'https://esdac.jrc.ec.europa.eu//Eudasm/UK/South-West_Scotland6.jpg': {'Scotland'},
#  'c01d7dcc-ff05-4773-9c0b-6de920bb2434': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kemaiko.jpg': set(),
#  '09adf1ad-a388-40e0-a61f-ba30d300cef9': {'Germany'},
#  '6b664e1e-15ff-4bcb-8cd6-fef048a653a6': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_shlu5c.jpg': {'St. Helena'},
#  '70304e68-c369-4c1b-8d54-79f48bc182c4': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/latinamerica/images/maps/download/uy13003_su.jpg': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Asia/images/maps/download/MY3006_4LU.jpg': set(),
#  'https://esdac.jrc.ec.europa.eu//images/Eudasm/Africa/images/maps/download/afr_kekili1.jpg': set()}

# %%
eval_Hybrid = eval_test(labeled_dataset,cleaned_hybrid_dict,return_table=True)
{print(f"{k}: {v}") for k, v in eval_Hybrid.items() if k != 'evaluation table'}
# Out:
# precision: 0.4444444444444444
# recall: 0.3065134099616858
# f1 score: 0.36281179138321995
# {None}

# %%
eval_Hybrid_geo = eval_test_geo_polygone(labeled_dataset,cleaned_hybrid_dict,return_table=True)
{print(f"{k}: {v}") for k, v in eval_Hybrid_geo.items() if k != 'evaluation table'}
# Out:
# precision area: 0.4639944646861015
# recall area: 0.4871166943051461
# {None}

# %%
merged_dict = {**eval_Hybrid, **eval_Hybrid_geo}
merged_evaluation_table = pd.concat([eval_Hybrid['evaluation table'], eval_Hybrid_geo['evaluation table']], axis=1)
merged_dict['evaluation table'] = merged_evaluation_table
Global_eval['Hybrid_2']=merged_dict
Global_eval['Hybrid_2']['evaluation table'].sort_values(by=['Recall'])[:20]
# Out:
#                                                                                                  Text  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...  General Soil Map Kauai Island Hawaii || Genera...
# a45c7a1f-3dc5-478f-9d25-50dacd607d02                Soil values from the agricultural soil valuati...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  """Kijabe. Sheet """"134/3"""". Y731 (D.O.S. 4...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Noodsberg. 2930BD. South Africa. [Noodsberg. S...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Present Land Use. West Malaysia. Sheet 1. || P...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Vavuniya District. Land Use. || Vavuniya Distr...
# f5bcf938-44cc-41fd-8d03-5543933d1d79                Web Map Service of the dataset 'Permafrost deg...
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                                           | || |
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Colombo and Kalutara Districts. Land Use. || C...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  land Use Map of Diful II Project. Ostan VII Ir...
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                WMS Service of datasets from the 'ZALF Focus A...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Soil Map. The Jilga Valley. Vol. IV-13. || Soi...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...  South America. Potential Population Supporting...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Enarotali. Seri IND-B1 Lembar M13-4. Edisi 1. ...
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...  Generalised soil map of the Netherlands || Gen...
# 10.1785/0120190121                                  Variability of ETAS Parameters in Global Subdu...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Regional Map of Land Resources and Potentialit...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Generalized Map of the Great Soil Groups of th...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  Formations Végétales et Domaine Forestier Nati...
# https://esdac.jrc.ec.europa.eu/resource-type/do...  Mercury in European topsoils: Anthropogenic so...
#
#                                                                                        Manual Labeled  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...                              {Kauai Island Hawaii}
# a45c7a1f-3dc5-478f-9d25-50dacd607d02                                                    {Brandenburg}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...             {Suid-Afrika, Noodsberg, South Africa}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                          {Malaysia, West Malaysia}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                {Vavuniya District}
# f5bcf938-44cc-41fd-8d03-5543933d1d79                                                         {Alaska}
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                                               {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Colombo District, Kalutara District, Kalutara...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                             {Iran}
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                                                    {Paulinenaue}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                            {Jilga}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                                    {South America}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                        {Enarotali}
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...                                      {Netherlands}
# 10.1785/0120190121                                                     {Maule, Aceh, Tohoku, Andaman}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                  {Garmsar, Tehran}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                        {Khuzistan}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                       {Madagascar}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                                 {European, Europe}
#
#                                                    Matching Labels  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...              {}
# a45c7a1f-3dc5-478f-9d25-50dacd607d02                            {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# f5bcf938-44cc-41fd-8d03-5543933d1d79                            {}
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                            {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                            {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...              {}
# 10.1785/0120190121                                              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...              {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...              {}
#
#                                                    Non-Matching Labels  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...                  {}
# a45c7a1f-3dc5-478f-9d25-50dacd607d02                         {Germany}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# f5bcf938-44cc-41fd-8d03-5543933d1d79                                {}
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                                {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...                  {}
# 10.1785/0120190121                                                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                  {}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                  {}
#
#                                                                                      Not Found Labels  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...                              {Kauai Island Hawaii}
# a45c7a1f-3dc5-478f-9d25-50dacd607d02                                                    {Brandenburg}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                                 {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...             {Suid-Afrika, Noodsberg, South Africa}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                          {Malaysia, West Malaysia}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                {Vavuniya District}
# f5bcf938-44cc-41fd-8d03-5543933d1d79                                                         {Alaska}
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                                               {}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...  {Colombo District, Kalutara District, Kalutara...
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                             {Iran}
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                                                    {Paulinenaue}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                            {Jilga}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                                    {South America}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                        {Enarotali}
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...                                      {Netherlands}
# 10.1785/0120190121                                                     {Maule, Aceh, Tohoku, Andaman}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                  {Garmsar, Tehran}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                        {Khuzistan}
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                                       {Madagascar}
# https://esdac.jrc.ec.europa.eu/resource-type/do...                                 {European, Europe}
#
#                                                     Recall  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...     0.0
# a45c7a1f-3dc5-478f-9d25-50dacd607d02                   0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# f5bcf938-44cc-41fd-8d03-5543933d1d79                   0.0
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                   0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                   0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...     0.0
# 10.1785/0120190121                                     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...     0.0
# https://esdac.jrc.ec.europa.eu/resource-type/do...     0.0
#
#                                                     percentage area match  \
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...                    0.0
# a45c7a1f-3dc5-478f-9d25-50dacd607d02                                  1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# f5bcf938-44cc-41fd-8d03-5543933d1d79                                  0.0
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                                  1.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                                  0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...                    0.0
# 10.1785/0120190121                                                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...                    0.0
# https://esdac.jrc.ec.europa.eu/resource-type/do...                    0.0
#
#                                                     precision area
# https://esdac.jrc.ec.europa.eu//images/Eudasm/U...         0.000000
# a45c7a1f-3dc5-478f-9d25-50dacd607d02                       0.079697
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         1.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# f5bcf938-44cc-41fd-8d03-5543933d1d79                       0.000000
# 5187f8c5-38ef-4b07-bc26-a5e257a8ef59                       1.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# 2f32fbe1-30fd-4472-8b97-e02267c34ca6                       0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/l...         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu//Eudasm/NL/neth_...         0.000000
# 10.1785/0120190121                                         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu//images/Eudasm/A...         0.000000
# https://esdac.jrc.ec.europa.eu/resource-type/do...         0.000000

# %% [markdown]
# ## Summary Evaluation Table

# %%
Global_eval
for k_glob, v_glob in Global_eval.items():
    print('-----------------------')
    print('Summary: ',k_glob)
    for k, v in v_glob.items():
        if k == 'evaluation table':
            continue
        print(f"--> {k}: {v:.3f}")
# Out:
# -----------------------
# Summary:  GliNER
# --> precision: 0.421
# --> recall: 0.625
# --> f1 score: 0.503
# --> recall area: 0.709
# --> precision area: 0.673
# -----------------------
# Summary:  OpenAI_1
# --> precision: 0.730
# --> recall: 0.747
# --> f1 score: 0.739
# --> recall area: 0.840
# --> precision area: 0.787
# -----------------------
# Summary:  OpenAI_2
# --> precision: 0.745
# --> recall: 0.728
# --> f1 score: 0.736
# --> recall area: 0.823
# --> precision area: 0.775
# -----------------------
# Summary:  Hybrid_1
# --> precision: 0.484
# --> recall: 0.337
# --> f1 score: 0.397
# --> recall area: 0.519
# --> precision area: 0.499
# -----------------------
# Summary:  Hybrid_2
# --> precision: 0.444
# --> recall: 0.307
# --> f1 score: 0.363
# --> precision area: 0.464
# --> recall area: 0.487
